# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Часть.-Приоритизация-гипотез" data-toc-modified-id="Часть.-Приоритизация-гипотез-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Часть. Приоритизация гипотез</a></span><ul class="toc-item"><li><span><a href="#Загружаем-данные-из-файла-hypothesis.csv." data-toc-modified-id="Загружаем-данные-из-файла-hypothesis.csv.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загружаем данные из файла <code>hypothesis.csv</code>.</a></span></li><li><span><a href="#Смотрим-и-преобразовываем-данные" data-toc-modified-id="Смотрим-и-преобразовываем-данные-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Смотрим и преобразовываем данные</a></span></li><li><span><a href="#Применим-фреймворк-ICE-для-приоритизации-гипотез-и-отсортируем-их-по-убыванию-приоритета" data-toc-modified-id="Применим-фреймворк-ICE-для-приоритизации-гипотез-и-отсортируем-их-по-убыванию-приоритета-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Применим фреймворк ICE для приоритизации гипотез и отсортируем их по убыванию приоритета</a></span></li><li><span><a href="#Применим-фреймворк-RICE-для-приоритизации-гипотез-и-отсортируем-их-по-убыванию-приоритета" data-toc-modified-id="Применим-фреймворк-RICE-для-приоритизации-гипотез-и-отсортируем-их-по-убыванию-приоритета-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Применим фреймворк RICE для приоритизации гипотез и отсортируем их по убыванию приоритета</a></span></li><li><span><a href="#Вывод-по-приоритезации-гипотез" data-toc-modified-id="Вывод-по-приоритезации-гипотез-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Вывод по приоритезации гипотез</a></span></li></ul></li><li><span><a href="#Часть.-Анализ-A/B-теста" data-toc-modified-id="Часть.-Анализ-A/B-теста-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Часть. Анализ A/B-теста</a></span><ul class="toc-item"><li><span><a href="#Загружаем-данные-из-файлов-orders.csv-и-visitors.csv" data-toc-modified-id="Загружаем-данные-из-файлов-orders.csv-и-visitors.csv-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Загружаем данные из файлов <code>orders.csv</code> и <code>visitors.csv</code></a></span></li><li><span><a href="#Смотрим-и-преобразовываем-данные" data-toc-modified-id="Смотрим-и-преобразовываем-данные-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Смотрим и преобразовываем данные</a></span></li><li><span><a href="#Соберем-все-нужные-комулятивные-данные" data-toc-modified-id="Соберем-все-нужные-комулятивные-данные-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Соберем все нужные комулятивные данные</a></span></li><li><span><a href="#Построим-график-кумулятивной-выручки-по-группам" data-toc-modified-id="Построим-график-кумулятивной-выручки-по-группам-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Построим график кумулятивной выручки по группам</a></span></li><li><span><a href="#Вывод-по-графику-кумулятивной-выручки-по-группам" data-toc-modified-id="Вывод-по-графику-кумулятивной-выручки-по-группам-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Вывод по графику кумулятивной выручки по группам</a></span></li><li><span><a href="#Построим-график-кумулятивного-среднего-чека-по-группам" data-toc-modified-id="Построим-график-кумулятивного-среднего-чека-по-группам-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Построим график кумулятивного среднего чека по группам</a></span></li><li><span><a href="#Вывод-по-графику-кумулятивного-среднего-чека-по-группам" data-toc-modified-id="Вывод-по-графику-кумулятивного-среднего-чека-по-группам-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Вывод по графику кумулятивного среднего чека по группам</a></span></li><li><span><a href="#Построим-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A" data-toc-modified-id="Построим-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Построим график относительного изменения кумулятивного среднего чека группы B к группе A</a></span></li><li><span><a href="#Вывод-по-графику-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A" data-toc-modified-id="Вывод-по-графику-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Вывод по графику относительного изменения кумулятивного среднего чека группы B к группе A</a></span></li><li><span><a href="#Построим-график-кумулятивной-конверсии-по-группам" data-toc-modified-id="Построим-график-кумулятивной-конверсии-по-группам-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Построим график кумулятивной конверсии по группам</a></span></li><li><span><a href="#Вывод-по-графику-кумулятивной-конверсии-по-группам" data-toc-modified-id="Вывод-по-графику-кумулятивной-конверсии-по-группам-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Вывод по графику кумулятивной конверсии по группам</a></span></li><li><span><a href="#Построим-график-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A" data-toc-modified-id="Построим-график-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Построим график относительного изменения кумулятивной конверсии группы B к группе A</a></span></li><li><span><a href="#Вывод-по-графику-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A" data-toc-modified-id="Вывод-по-графику-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Вывод по графику относительного изменения кумулятивной конверсии группы B к группе A</a></span></li><li><span><a href="#Построим-точечный-график-количества-заказов-по-пользователям" data-toc-modified-id="Построим-точечный-график-количества-заказов-по-пользователям-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>Построим точечный график количества заказов по пользователям</a></span></li><li><span><a href="#Вывод-по-графику-количества-заказов-по-пользователям" data-toc-modified-id="Вывод-по-графику-количества-заказов-по-пользователям-2.15"><span class="toc-item-num">2.15&nbsp;&nbsp;</span>Вывод по графику количества заказов по пользователям</a></span></li><li><span><a href="#Посчитаем-95-й-и-99-й-перцентили-количества-заказов-на-пользователя-и-выберем-границу-для-определения-аномальных-пользователей" data-toc-modified-id="Посчитаем-95-й-и-99-й-перцентили-количества-заказов-на-пользователя-и-выберем-границу-для-определения-аномальных-пользователей-2.16"><span class="toc-item-num">2.16&nbsp;&nbsp;</span>Посчитаем 95-й и 99-й перцентили количества заказов на пользователя и выберем границу для определения аномальных пользователей</a></span></li><li><span><a href="#Построим-точечный-график-стоимостей-заказов" data-toc-modified-id="Построим-точечный-график-стоимостей-заказов-2.17"><span class="toc-item-num">2.17&nbsp;&nbsp;</span>Построим точечный график стоимостей заказов</a></span></li><li><span><a href="#Вывод-по-точечному-графику-стоимостей-заказов" data-toc-modified-id="Вывод-по-точечному-графику-стоимостей-заказов-2.18"><span class="toc-item-num">2.18&nbsp;&nbsp;</span>Вывод по точечному графику стоимостей заказов</a></span></li><li><span><a href="#Посчитаем-95-й-и-99-й-перцентили-стоимости-заказов.-Выберем-границу-для-определения-аномальных-заказов" data-toc-modified-id="Посчитаем-95-й-и-99-й-перцентили-стоимости-заказов.-Выберем-границу-для-определения-аномальных-заказов-2.19"><span class="toc-item-num">2.19&nbsp;&nbsp;</span>Посчитаем 95-й и 99-й перцентили стоимости заказов. Выберем границу для определения аномальных заказов</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-конверсии-между-группами-по-«сырым»-данным" data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-конверсии-между-группами-по-«сырым»-данным-2.20"><span class="toc-item-num">2.20&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в конверсии между группами по «сырым» данным</a></span></li><li><span><a href="#Вывод-по-статистической-значимости-различий-в-конверсии-между-группами-по-«сырым»-данным" data-toc-modified-id="Вывод-по-статистической-значимости-различий-в-конверсии-между-группами-по-«сырым»-данным-2.21"><span class="toc-item-num">2.21&nbsp;&nbsp;</span>Вывод по статистической значимости различий в конверсии между группами по «сырым» данным</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным" data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным-2.22"><span class="toc-item-num">2.22&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным</a></span></li><li><span><a href="#Вывод-по-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным" data-toc-modified-id="Вывод-по-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным-2.23"><span class="toc-item-num">2.23&nbsp;&nbsp;</span>Вывод по статистической значимости различий в среднем чеке заказа между группами по «сырым» данным</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-конверсии-между-группами-по-«очищенным»-данным" data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-конверсии-между-группами-по-«очищенным»-данным-2.24"><span class="toc-item-num">2.24&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в конверсии между группами по «очищенным» данным</a></span></li><li><span><a href="#Вывод-по-статистической-значимость-различий-в-конверсии-между-группами-по-«очищенным»-данным" data-toc-modified-id="Вывод-по-статистической-значимость-различий-в-конверсии-между-группами-по-«очищенным»-данным-2.25"><span class="toc-item-num">2.25&nbsp;&nbsp;</span>Вывод по статистической значимость различий в конверсии между группами по «очищенным» данным</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным" data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным-2.26"><span class="toc-item-num">2.26&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным</a></span></li><li><span><a href="#Вывод-по-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным" data-toc-modified-id="Вывод-по-статистической-значимости-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным-2.27"><span class="toc-item-num">2.27&nbsp;&nbsp;</span>Вывод по статистической значимости различий в среднем чеке заказа между группами по «очищенным» данным</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Проверка списока гипотез для увеличения выручки в крупном интернет-магазине.

# %% [markdown]
# **Цель исследования**
#
# Для увеличения выручки в крупном интернет-магазине небходимо:
#
# - приоритизировать гипотезы;
# - запустить A/B-тест;
# - проанализировать результаты.
#
# **Ход исследования**
#
# Исследование состоит из двух основных частей:
#
# **Часть 1**. Приоритизация гипотез. Входные данные мы получим из файла: `hypothesis.csv`
#
# Задачи:
#
# - применим фреймворк `ICE` для приоритизации гипотез. Отсортируем их по убыванию приоритета;
# - применим фреймворк `RICE` для приоритизации гипотез. Отсортируем их по убыванию приоритета;
# - Укажем, как изменилась приоритизация гипотез при применении `RICE` вместо `ICE`. Объясним, почему так произошло.
#
#
# **Часть 2**. Анализ A/B-теста. Входные данные мы получим из файлов: `orders.csv` и `visitors.csv`
#
# Задачи:
#
# Проанализирем A/B-тест:
#
# - построим график кумулятивной выручки по группам. Сделаем выводы и предположения;
# - построим график кумулятивного среднего чека по группам. Сделаем выводы и предположения;
# - построим график относительного изменения кумулятивного среднего чека группы B к группе A. Сделаем выводы и предположения;
# - построим график кумулятивной конверсии по группам. Сделаем выводы и предположения;
# - построим график относительного изменения кумулятивной конверсии группы B к группе A. Сделаем выводы и предположения;
# - построим точечный график количества заказов по пользователям. Сделаем выводы и предположения;
# - посчитаем 95-й и 99-й перцентили количества заказов на пользователя. Выберем границу для определения аномальных пользователей;
# - построим точечный график стоимостей заказов. Сделаем выводы и предположения;
# - посчитаем 95-й и 99-й перцентили стоимости заказов. Выберем границу для определения аномальных заказов;
# - посчитаем статистическую значимость различий в конверсии между группами по «сырым» данным. Сделаем выводы и предположения;
# - посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделаем выводы и предположения;
# - посчитаем статистическую значимость различий в конверсии между группами по «очищенным» данным. Сделаем выводы и предположения;
# - посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделаем выводы и предположения;
# - примем решение по результатам теста и объясним его;
#
# Варианты решений:
#
# 1. Остановить тест, зафиксировать победу одной из групп.
# 2. Остановить тест, зафиксировать отсутствие различий между группами.
# 3. Продолжить тест.
#
# **Описание данных**
#
# Данные для первой части
#
#
# Файл `hypothesis.csv`:
#
# - `Hypothesis` — краткое описание гипотезы;
# - `Reach` — охват пользователей по 10-балльной шкале;
# - `Impact` — влияние на пользователей по 10-балльной шкале;
# - `Confidence` — уверенность в гипотезе по 10-балльной шкале;
# - `Efforts` — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
#
#
# Данные для второй части
#
#
# Файл `orders.csv`:
#
# - `transactionId` — идентификатор заказа;
# - `visitorId` — идентификатор пользователя, совершившего заказ;
# - `date` — дата, когда был совершён заказ;
# - `revenue` — выручка заказа;
# - `group` — группа A/B-теста, в которую попал заказ.
#
# Файл `visitors.csv`:
#
# - `date` — дата;
# - `group` — группа A/B-теста;
# - `visitors` — количество пользователей в указанную дату в указанной группе A/B-теста

# %% [markdown]
# ## Часть. Приоритизация гипотез

# %% [markdown]
# ### Загружаем данные из файла `hypothesis.csv`.

# %% [markdown]
# Импротируем библиотеки

# %%
# импортируем библиотеку pandas
import pandas as pd
# импортируем библиотеку matplotlib
import matplotlib.pyplot as plt
# импортируем библиотеку seaborn
import seaborn as sns
# импортируем библиотеку math
import math
# импортируем библиотеку numpy
import numpy as np
# импортируем библиотеку stats
from scipy import stats as st
# импортируем класс timedelta() модуля datetime представляет собой продолжительность, разницу между двумя датами или временем
from datetime import datetime, timedelta
import datetime as dt

# %% [markdown]
# Используем настройки `pandas`

# %%
# используем настроики "Pandas". Настроим вывод таблиц так, чтобы все колонки были видны. 
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_colwidth', 200)

# %% [markdown]
# Прочитаем файл - `hypothesis.csv` из папки `datasets`.

# %%
# чтение файла
try:
    hypothesis = pd.read_csv('C:/Users/Woode/Projects yandex/Ab test hypothesis/hypothesis.csv')
except:
    hypothesis = pd.read_csv('/datasets/hypothesis.csv')

# %% [markdown]
# ### Смотрим и преобразовываем данные

# %%
# посмотрим первые 10 записей таблицы hypothesis
display(hypothesis.head(10))
# Out:
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %% [markdown]
# Посмотрим общую информацию о таблице `hypothesis` и количество пропусков

# %%
# скопируем датафрейм
temp_v = hypothesis.copy()
# выведем список колонок
list_v = ['Hypothesis', 'Reach', 'Impact', 'Confidence', 'Efforts']
# посмотрим общую информацию
print(temp_v.info())
# посмотрим количество строк и столбцов
print('Количество строк и колонок', temp_v.shape)
# посмотрим есть ли дубликаты в данных
print('Количество дубликатов в данных:', hypothesis.duplicated().sum())
# посмотрим статистические показатели
display('Статистические показатели:', hypothesis.describe())
# напишем цикл
for col_v in list_v:
    print('-' * 50)
    print(col_v, temp_v[col_v].sort_values().unique())
    print(col_v,': кол-во NaN',temp_v[col_v].isna().sum(),
        ', процент NaN', round(temp_v[col_v].isna().sum()/len(temp_v)*100, 2),'%')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hypothesis  9 non-null      object
#  1   Reach       9 non-null      int64
#  2   Impact      9 non-null      int64
#  3   Confidence  9 non-null      int64
#  4   Efforts     9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 488.0+ bytes
# None
# Количество строк и колонок (9, 5)
# Количество дубликатов в данных: 0
# 'Статистические показатели:'
#            Reach     Impact  Confidence    Efforts
# count   9.000000   9.000000    9.000000   9.000000
# mean    4.777778   4.777778    5.555556   4.888889
# std     3.153481   3.192874    3.045944   2.803767
# min     1.000000   1.000000    1.000000   1.000000
# 25%     3.000000   3.000000    3.000000   3.000000
# 50%     3.000000   3.000000    7.000000   5.000000
# 75%     8.000000   7.000000    8.000000   6.000000
# ...

# %%
# приводим навзания всех колонок к нижнему регистрку в таблице hypothesis
hypothesis.columns = hypothesis.columns.str.lower()

# %% [markdown]
# Привили названия всех колонок к нижнему регистру. Видим что в таблице `hypothesis` 9 строк и 5 колонок. Пропусков и дубликатов в данных нет.

# %% [markdown]
# ### Применим фреймворк ICE для приоритизации гипотез и отсортируем их по убыванию приоритета

# %%
# посмотрим таблицу hypothesis
display(hypothesis)
# Out:
#                                                                                                      hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %%
# посчитаем 'ICE' для гипотез 
# добавим полученные значения 'ICE' к существующей таблице в столбец 'ICE' 
hypothesis['ICE'] = hypothesis['impact'] * hypothesis['confidence'] / hypothesis['efforts']

# выведем столбцы 'hypothesis' и 'ICE', отсортированные по столбцу 'ICE', округлим до целого числа
display(hypothesis[['hypothesis', 'ICE']].sort_values(by='ICE', ascending=False).round())
# Out:
#                                                                                                      hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# Наиболее перспективные гипотизы по ICE:
#
# 1. Запустить акцию, дающую скидку на товар в день рождения
# 2. Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 3. Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 4. Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 5. Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа

# %% [markdown]
# ### Применим фреймворк RICE для приоритизации гипотез и отсортируем их по убыванию приоритета

# %%
# посчитаем 'RICE' для гипотез 
# добавим полученные значения 'RICE' к существующей таблице в столбец 'RICE' 
hypothesis['RICE'] = hypothesis['reach'] * hypothesis['impact'] * hypothesis['confidence'] / hypothesis['efforts']

# выведем столбцы 'hypothesis' и 'RICE', отсортированные по столбцу 'RICE', округлим до целого числа
display(hypothesis[['hypothesis', 'RICE']].sort_values(by='RICE', ascending=False).round())
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# Наиболее перспективные гипотизы по RICE:
#
# 1. Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2. Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3. Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 4. Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 5. Запустить акцию, дающую скидку на товар в день рождения

# %% [markdown]
# ### Вывод по приоритезации гипотез
# Пятерка гипотез остается неизменной по `ICE` или `RICE`, но меняется последовательность.
# Так как в `RICE` входит параметр `reach`, которого нет в `ICE`, именно из-за него изменилась приоритизация. Фреймворк `RICE` является более информативным для A/B теста.

# %% [markdown]
# ## Часть. Анализ A/B-теста

# %% [markdown]
# ### Загружаем данные из файлов `orders.csv` и `visitors.csv`

# %%
# чтение файлов orders.csv и visitors.csv
try:
    orders = pd.read_csv('C:/Users/Woode/Projects yandex/Ab test hypothesis/orders.csv')
    visitors = pd.read_csv('C:/Users/Woode/Projects yandex/Ab test hypothesis/visitors.csv')
except:
    orders = pd.read_csv('/datasets/orders.csv')
    visitors = pd.read_csv('/datasets/visitors.csv')

# %% [markdown]
# ### Смотрим и преобразовываем данные

# %%
# посмотрим первые 5 записей таблицы orders
display(orders.head())
# Out:
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B

# %%
# скопируем датафрейм
temp_v = orders.copy()
# выведем список колонок
list_v = ['transactionId', 'visitorId', 'date', 'revenue', 'group']
# посмотрим общую информацию
print(temp_v.info())
# посмотрим количество строк и столбцов
print('Количество строк и колонок', temp_v.shape)
# посмотрим есть ли дубликаты в данных
print('Количество дубликатов в данных:', orders.duplicated().sum())
# посмотрим статистические показатели
display('Статистические показатели:', orders.describe())
# напишем цикл
for col_v in list_v:
    print('-' * 50)
    print(col_v, temp_v[col_v].sort_values().unique())
    print(col_v,': кол-во NaN',temp_v[col_v].isna().sum(),
        ', процент NaN', round(temp_v[col_v].isna().sum()/len(temp_v)*100, 2),'%')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB
# None
# Количество строк и колонок (1197, 5)
# Количество дубликатов в данных: 0
# 'Статистические показатели:'
#        transactionId     visitorId       revenue
# count   1.197000e+03  1.197000e+03  1.197000e+03
# mean    2.155621e+09  2.165960e+09  8.348006e+03
# std     1.229085e+09  1.236014e+09  3.919113e+04
# min     1.062393e+06  5.114589e+06  5.000000e+01
# 25%     1.166776e+09  1.111826e+09  1.220000e+03
# 50%     2.145194e+09  2.217985e+09  2.978000e+03
# 75%     3.237740e+09  3.177606e+09  8.290000e+03
# ...

# %% [markdown]
# Преобразуем тип данных в колонке `date` в datetime

# %%
# поменяем тип данных в колонке 'date' с 'object' на 'datetime'
orders['date'] = pd.to_datetime(orders['date'])

# %% [markdown]
# В таблице `orders` 5 колонок и 1 197 строчек. Пропусков и дубликатов нет.

# %%
# посмотрим первые 5 записей таблицы orders
display(visitors.head())
# Out:
#          date group  visitors
# 0  2019-08-01     A       719
# 1  2019-08-02     A       619
# 2  2019-08-03     A       507
# 3  2019-08-04     A       717
# 4  2019-08-05     A       756

# %%
# скопируем датафрейм
temp_v = visitors.copy()
# выведем список колонок
list_v = ['date', 'group', 'visitors']
# посмотрим общую информацию
print(temp_v.info())
# посмотрим количество строк и столбцов
print('Количество строк и колонок', temp_v.shape)
# посмотрим есть ли дубликаты в данных
print('Количество дубликатов в данных:', visitors.duplicated().sum())
# посмотрим статистические показатели
display('Статистические показатели:', visitors.describe())
# напишем цикл
for col_v in list_v:
    print('-' * 50)
    print(col_v, temp_v[col_v].sort_values().unique())
    print(col_v,': кол-во NaN',temp_v[col_v].isna().sum(),
        ', процент NaN', round(temp_v[col_v].isna().sum()/len(temp_v)*100, 2),'%')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     object
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB
# None
# Количество строк и колонок (62, 3)
# Количество дубликатов в данных: 0
# 'Статистические показатели:'
#          visitors
# count   62.000000
# mean   607.290323
# std    114.400560
# min    361.000000
# 25%    534.000000
# 50%    624.500000
# 75%    710.500000
# max    770.000000
# --------------------------------------------------
# date ['2019-08-01' '2019-08-02' '2019-08-03' '2019-08-04' '2019-08-05'
#  '2019-08-06' '2019-08-07' '2019-08-08' '2019-08-09' '2019-08-10'
#  '2019-08-11' '2019-08-12' '2019-08-13' '2019-08-14' '2019-08-15'
#  '2019-08-16' '2019-08-17' '2019-08-18' '2019-08-19' '2019-08-20'
# ...

# %%
# поменяем тип данных в колонке 'date' с 'object' на 'datetime'
visitors['date'] = pd.to_datetime(visitors['date'])

# %%
visitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     datetime64[ns]
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.6+ KB

# %% [markdown]
# В таблице `visitors` 3 колоноки и 62 строчеки. Пропусков и дубликатов нет.

# %%
# посмотрим сколько групп есть в таблице visitors
print('Сколько групп для имеется в таблице "visitors" для A/B теста:', visitors['group'].unique())
# посмотрим сколько групп есть в таблице orders
print('Сколько групп для имеется в таблице "orders" для A/B теста:', orders['group'].unique())
# Out:
# Сколько групп для имеется в таблице "visitors" для A/B теста: ['A' 'B']
# Сколько групп для имеется в таблице "orders" для A/B теста: ['B' 'A']

# %% [markdown]
# Для A/B теста у нас есть две группы: A и B.

# %%
# количество покупателей в каждой группе
display(orders.groupby('group').agg({'visitorId' : 'count'}).reset_index())
# Out:
#   group  visitorId
# 0     A        557
# 1     B        640

# %% [markdown]
# Количество покупателей:
# * группа `A` - `557`
# * группа `B` - `640`

# %%
# количество уникальных покупателей в каждой группе
display(orders.groupby('group').agg({'visitorId' : 'nunique'}).reset_index())
# Out:
#   group  visitorId
# 0     A        503
# 1     B        586

# %% [markdown]
# Количество уникальных покупателей:
# * группа `A` - `503`
# * группа `B` - `586`

# %%
# удаляем явные дубликаты из колонок visitorId и group
unique_visitors = orders[['visitorId', 'group']].drop_duplicates()

# %%
# пользователи, которые есть в обеих группах
unique_visitors[unique_visitors['visitorId'].duplicated() == True]
# Out:
#        visitorId group
# 41     237748145     A
# 114   4256040402     A
# 117   2038680547     A
# 197   2716752286     A
# 246    199603092     B
# 249   3234906277     A
# 252   3803269165     B
# 254   2686716486     B
# 256    457167155     A
# 267   2579882178     B
# 279   1648269707     A
# 330   1738359350     B
# 380   2458001652     B
# 391   2378935119     B
# 432   3202540741     B
# 453    351125977     A
# 455   2954449915     B
# 479   2927087541     B
# 497   3951559397     A
# 516   2044997962     B
# 536   3984495233     A
# 561   3957174400     B
# 606   3891541246     B
# 674   1230306981     B
# 677   1294878855     A
# 682   4266935830     B
# 687   1614305549     A
# 688   1333886533     B
# 703      8300375     A
# 732    477780734     B
# 782   1668030113     A
# 783   1959144690     B
# 809   3717692402     A
# 832   3766097110     B
# 857   2780786433     B
# 879   1801183820     A
# 900   1316129916     B
# 914   1602967004     A
# 936    393266494     B
# ...

# %%
# количество пользователей, которое есть в обеих группах
display(unique_visitors['visitorId'].duplicated().sum())
# Out:
# 58

# %% [markdown]
# Количество пользователей, которые встречаются в обеих группах: `58`

# %% [markdown]
# ### Соберем все нужные комулятивные данные

# %%
# создаем массив уникальных пар значений дат и групп теста
datesGroups = orders[['date','group']].drop_duplicates()

# получаем агрегированные кумулятивные по дням данные о заказах
ordersAggregated = datesGroups.apply(lambda x: orders[np.logical_and(orders['date'] <= x['date'], orders['group'] == x['group'])]\
                                     .agg({'date' : 'max', 'group' : 'max', 'transactionId' : 'nunique', 'visitorId' : 'nunique', 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])

# Аналогично получим агрегированные кумулятивные по дням данные о посетителях интернет-магазина:
visitorsAggregated = datesGroups.apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])]\
                                       .agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group'])

# объединяем кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия
cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# посмотрим первые 5 строк таблицы 'cumulativeData'
display(cumulativeData.head())

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]

# посмотрим первые 5 строк таблицы 'cumulativeRevenueA'
display(cumulativeRevenueA.head())

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]

# посмотрим первые 5 строк таблицы 'cumulativeRevenueB'
display(cumulativeRevenueB.head())
# Out:
#         date group  orders  buyers  revenue  visitors
# 0 2019-08-01     A      24      20   148579       719
# 1 2019-08-01     B      21      20   101217       713
# 2 2019-08-02     A      44      38   242401      1338
# 3 2019-08-02     B      45      43   266748      1294
# 4 2019-08-03     A      68      62   354874      1845
#         date  revenue  orders
# 0 2019-08-01   148579      24
# 2 2019-08-02   242401      44
# 4 2019-08-03   354874      68
# 6 2019-08-04   425699      84
# 8 2019-08-05   549917     109
#         date  revenue  orders
# 1 2019-08-01   101217      21
# 3 2019-08-02   266748      45
# 5 2019-08-03   380996      61
# 7 2019-08-04   489567      78
# 9 2019-08-05   581995     101

# %% [markdown]
# ### Построим график кумулятивной выручки по группам

# %%
# укажем размер графика
plt.figure(figsize=(13, 8))
# строим график выручки группы А
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')

# строим график выручки группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')

# включим сетку
plt.grid()

# заголовок графика
plt.title('График кумулятивной выручки по группам')

# легенда
plt.legend()

# подпись оси X
plt.xlabel('Даты')

# подпись оси Y
plt.ylabel('Выручка')

# убираем технические надписи
plt.show()

# %% [markdown]
# ### Вывод по графику кумулятивной выручки по группам
# С начала августа и до его середины сегмент `A` и `В` шли очень близко друг к другу, но затем сегмент `B` стал заметно выше по показателям выручки чем `A`. Видимо в этот период были отличные продажи или скорее аномальные, которые случились буквально за сутки.

# %% [markdown]
# ### Построим график кумулятивного среднего чека по группам

# %%
# укажем размер графика
plt.figure(figsize=(13, 8))

# строим график среднего чека для группы А
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')

# строим график среднего чека для группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B')

# включим сетку
plt.grid()

# заголовок графика
plt.title('График кумулятивного среднего чека по группам')

# легенда
plt.legend()

# подпись оси X
plt.xlabel('Даты')

# подпись оси Y
plt.ylabel('Средний чек')

# убираем технические надписи
plt.show()

# %% [markdown]
# ### Вывод по графику кумулятивного среднего чека по группам
# Средний чек по сегментам `A` и `B` показывает рост до середины месяца. Затем сегмент `A` немного снижается и остается на одном уровне, а сегмент `B` резко возрастает 18 августа - это похоже на аномально большие заказы.

# %% [markdown]
# ### Построим график относительного изменения кумулятивного среднего чека группы B к группе A

# %%
# собираем данные обеих групп в одном датафрейме 'mergedCumulativeRevenue'
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

# укажем размер графика
plt.figure(figsize=(13, 8))

# cтроим график отношение средних чеков
plt.plot(mergedCumulativeRevenue['date'], (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/(mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1)

# добавляем ось X
plt.axhline(y=0, color='black', linestyle='--')

# включим сетку
plt.grid()

# заголовок графика
plt.title('График относительного изменения кумулятивного среднего чека группы B к группе A')

# подпись оси X
plt.xlabel('Даты')

# подпись оси Y
plt.ylabel('Колебания в %')

# убираем технические надписи
plt.show()

# %% [markdown]
# ### Вывод по графику относительного изменения кумулятивного среднего чека группы B к группе A
# Наблюдаются резкие скачки 4, 6 и 18 августа. Как было замечено ранее у сегмента `B` 18 августа были аномально большие заказы.

# %% [markdown]
# ### Построим график кумулятивной конверсии по группам

# %%
# считаем кумулятивную конверсию
cumulativeData['conversion'] = cumulativeData['orders']/cumulativeData['visitors']

# отделяем данные по группе A
cumulativeDataA = cumulativeData[cumulativeData['group']=='A']

# отделяем данные по группе B
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']

# укажем размер графика
plt.figure(figsize=(13, 8))

# строим графики
plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='B')

# легенда
plt.legend()

# задаем масштаб осей
plt.axis([dt.datetime(2019, 8, 1), dt.datetime(2019, 9, 1), 0.026, 0.038])

# включим сетку
plt.grid()

# заголовок графика
plt.title('График кумулятивной конверсии по группам')

# подпись оси X
plt.xlabel('Даты')

# подпись оси Y
plt.ylabel('Колебания в %')

# убираем технические надписи
plt.show()

# %% [markdown]
# ### Вывод по графику кумулятивной конверсии по группам
# В начале теста конверсия сегмента `B` была ниже сегмента `A`, но после 6 августа она стала лидером. Абсолютное значение колебания в ходе всего теста от `2,9%` до `3,7%`. К концу теста значение сегмента `A` держится на уровне `3%`, а сегмента `B` на уровне `3,4%`.

# %% [markdown]
# ### Построим график относительного изменения кумулятивной конверсии группы B к группе A

# %%
# собираем данные обеих групп в одном датафрейме 'mergedCumulativeConversions'
mergedCumulativeConversions = cumulativeDataA[['date','conversion']].merge(cumulativeDataB[['date','conversion']], left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

# укажем размер графика
plt.figure(figsize=(13, 8))

# cтроим график относительного изменения кумулятивной конверсии группы B к группе A
plt.plot(mergedCumulativeConversions['date'], mergedCumulativeConversions['conversionB']/mergedCumulativeConversions['conversionA']-1, label="Относительный прирост конверсии группы B относительно группы A")

# легенда
plt.legend()

# добавляем ось X = 0
plt.axhline(y=0, color='black', linestyle='--')

# добавляем ось X = -0.1
plt.axhline(y=-0.1, color='grey', linestyle='--')

# добавляем ось X = 0.1
plt.axhline(y=0.1, color='lightgrey', linestyle='--')

# задаем масштаб осей
plt.axis([dt.datetime(2019, 8, 1), dt.datetime(2019, 9, 1), -0.2, 0.3])

# включим сетку
plt.grid()

# заголовок графика
plt.title('График относительного изменения кумулятивной конверсии группы B к группе A')

# подпись оси X
plt.xlabel('Даты')

# подпись оси Y
plt.ylabel('Колебания в %')

# убираем технические надписи
plt.show()

# %% [markdown]
# ### Вывод по графику относительного изменения кумулятивной конверсии группы B к группе A
# В начале теста сегмент `B` проигрывает сегменту `A`. С 6 августа сегмент `B` вырывается вперед. 15 августа заметен пик в `20%` конверсии затем до конца месяца сегмент `B` снижается до `10%`.

# %% [markdown]
# ### Построим точечный график количества заказов по пользователям

# %% [markdown]
# Подсчитаем количество заказов по пользователям и посмотрим на результат

# %%
# сгруппируем заказы по пользователям
ordersByUsers = (
    orders.groupby('visitorId', as_index=False)
    .agg({'transactionId': 'nunique'})
)

# поменяем названия колонок на visitorId и orders
ordersByUsers.columns = ['visitorId', 'orders']

# посмотрим 10 строчек таблицы
display(ordersByUsers.sort_values(by='orders', ascending=False).head(10))
# Out:
#        visitorId  orders
# 1023  4256040402      11
# 591   2458001652      11
# 569   2378935119       9
# 487   2038680547       8
# 44     199603092       5
# 744   3062433592       5
# 55     237748145       5
# 917   3803269165       5
# 299   1230306981       5
# 897   3717692402       5

# %% [markdown]
# Есть пользователи, которые совершали 5, 8, 9, 11 заказов.

# %% [markdown]
# Теперь построим точечный график

# %%
x_values = pd.Series(range(0,len(ordersByUsers)))

# укажем размер графика
plt.figure(figsize=(13, 8))

# построим точечный график
plt.scatter(x_values, ordersByUsers['orders'])

# заголовок графика
plt.title('Точечный график количества заказов по пользователям')

# подпись оси X
plt.xlabel('Количество пользователей')

# подпись оси Y
plt.ylabel('Количество заказов')

# убираем технические надписи
plt.show()

# %% [markdown]
# ### Вывод по графику количества заказов по пользователям
# Исходя из данных, пользователи делают в основном один заказ, в редком случае два. И в крайне редком случае от 5 до 11 заказов это можно было бы считать аномальным, но их точная доля не ясна. Для того, чтобы точно оценить аномалии нужно посчитать процентильи.

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили количества заказов на пользователя и выберем границу для определения аномальных пользователей

# %% [markdown]
# Посчитаем выборочные перцентили количества заказов на одного пользователя

# %%
print(np.percentile(ordersByUsers['orders'], [95, 99]))
# Out:
# [2. 4.]

# %% [markdown]
# По выборочным процетильям видно, что только `5%` пользователей совершали больше двух заказов. И `1%` пользователей совершили `4` заказа. Разумно выбрать `2` заказа на одного пользователя за верхнюю границу числа заказов, и отсеять аномальных пользователей по ней.

# %% [markdown]
# ### Построим точечный график стоимостей заказов

# %%
orders_rev = pd.Series(range(0,len(orders['revenue'])))

# укажем размер графика
plt.figure(figsize=(13, 8))

# построим точечный график
plt.scatter(orders_rev, orders['revenue'])

# заголовок графика
plt.title('Точечный график стоимостей заказов')

# подпись оси X
plt.xlabel('Количество пользователей')

# подпись оси Y
plt.ylabel('Выручка')

# убираем технические надписи
plt.show()

# %% [markdown]
# Увеличем маштаб графика до 200 000 ед. выручки

# %%
orders_rev = pd.Series(range(0,len(orders['revenue'])))

# укажем размер графика
plt.figure(figsize=(13, 8))

# построим точечный график
plt.scatter(orders_rev, orders['revenue'])

# увеличем маштаб оси y до 200 000 ед. выручки.
plt.ylim([0, 200000])

# заголовок графика
plt.title('Точечный график стоимостей заказов')

# подпись оси X
plt.xlabel('Количество пользователей')

# подпись оси Y
plt.ylabel('Выручка')

# убираем технические надписи
plt.show()

# %%
# посмотрим на 10 строчек самых дорогих заказов
display(orders[['visitorId', 'revenue']].sort_values(by='revenue', ascending=False).head(10))
# Out:
#        visitorId  revenue
# 425   1920142716  1294500
# 1196  2108080724   202740
# 858   1316129916    93940
# 1136  1307669133    92550
# 744    888512513    86620
# 682   4266935830    78990
# 662   4266935830    78990
# 743   4133034833    67990
# 1103  1164614297    66350
# 1099   148427295    65710

# %% [markdown]
# ### Вывод по точечному графику стоимостей заказов
# Из данных видно, что пользователи делают заказы не ботльше `30 000 ед.` На графике видны две явные аномалии на `1 294 500 ед.` и `202 740 ед.` Для того, чтобы точно оценить аномалии нужно посчитать процентильи.

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили стоимости заказов. Выберем границу для определения аномальных заказов

# %%
print(np.percentile(orders['revenue'], [95, 99]))
# Out:
# [28000.  58233.2]

# %% [markdown]
# По выборочным процетильям видно, что только `5%` заказов дороже `28 000 ед`. И `1%` заказов `58 233,2 ед`. Разумно выбрать `28 000 ед`. за верхнюю границу стоимости заказов, и отсеять аномальных пользователей по ней.

# %% [markdown]
# ### Посчитаем статистическую значимость различий в конверсии между группами по «сырым» данным

# %% [markdown]
# Для теста будем использовать статестический критерий `Манна-Уитни` основанный на структурном подходе, или непараметрический.
#
# Главное отличие непараметрических методов в том, что они работают с рангами, — номерами значений в упорядоченном ряду, — никак не учитывая сами значения. Поэтому к ним прибегают тогда, когда работа с самими значениями невозможна из-за выбросов, сильно сдвигающих параметрические результаты. В данных есть выбросы, поэтому статистический критерий `Манна-Уитни` здесь подойдет.
#
# Сформулируем гипотезы:
#  * Нулевая: различия в конверсиях между группами нет
#  * Альтернативная: различия в конверсиях между группами есть

# %%
# создадим переменные ordersByUsersA и ordersByUsersB со столбцами ['visitorId', 'transactionId']. 
# в них для пользователей, которые заказывали хотя бы 1 раз, укажем число совершённых заказов

ordersByUsersA = (
    orders[orders['group'] == 'A']
    .groupby('visitorId', as_index=False)
    .agg({'transactionId': pd.Series.nunique})
)

# меняем названия колонок на visitorId и orders
ordersByUsersA.columns = ['visitorId', 'orders']

ordersByUsersB = (
    orders[orders['group'] == 'B']
    .groupby('visitorId', as_index=False)
    .agg({'transactionId': pd.Series.nunique})
)

# меняем названия колонок на visitorId и orders
ordersByUsersB.columns = ['visitorId', 'orders']


# Объявим переменные sampleA и sampleB, в которых пользователям из разных групп будет соответствовать количество заказов.
# Тем, кто ничего не заказал, будут соответствовать нули. Это нужно, чтобы подготовить выборки к проверке критерием Манна-Уитни

sampleA = pd.concat(
    [
        ordersByUsersA['orders'],
        pd.Series(
            0,
            index=np.arange(
                visitors[visitors['group']=='A']['visitors'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleB = pd.concat(
    [
        ordersByUsersB['orders'],
        pd.Series(
            0,
            index=np.arange(
                visitors[visitors['group']=='B']['visitors'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)


alpha = 0.05  # критический уровень статистической значимости

results = st.mannwhitneyu(sampleA, sampleB)

print('p-значение: ','{0:.3f}'.format(results.pvalue))

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: разница статистически значима')
else:
    print(
        'Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя'
    )

# посмотрим относительный прирост конверсии группы B к группе A
print('Относительный прирост конверсии группы B равен:','{0:.3f}'.format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# p-значение:  0.017
# Отвергаем нулевую гипотезу: разница статистически значима
# Относительный прирост конверсии группы B равен: 0.138

# %% [markdown]
# ### Вывод по статистической значимости различий в конверсии между группами по «сырым» данным
# Тест показал, что статестическая разница в конверсии у группы `A` и `B` есть. Относительный прирост конверсии группы `B` равен `13.8%`.

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным

# %% [markdown]
# Сформулируем гипотезы:
#  * Нулевая: различия в среднем чеке заказа между группами нет
#  * Альтернативная: различия в среднем чеке заказа между группами есть

# %%
# Чтобы рассчитать статистическую значимость различий в среднем чеке, передадим критерию mannwhitneyu() данные о выручке с заказов.
# А ещё найдём относительные различия в среднем чеке между группами:
print('p-value равен:','{0:.3f}'.format(st.mannwhitneyu(orders[orders['group']=='A']['revenue'], orders[orders['group']=='B']['revenue'])[1]))
print('Средний чек группы B выше на:', '{0:.3f}'.format(orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1))
# Out:
# p-value равен: 0.729
# Средний чек группы B выше на: 0.259

# %% [markdown]
# ### Вывод по статистической значимости различий в среднем чеке заказа между группами по «сырым» данным
# Тест показал, что различия в в среднем чеке заказа между группами `A` и `B` есть.
# Средний чек группы `B` выше на `25.9%` — среднего чека группы `A`. Это связано с аномалиями, которые есть в "сырых" данных. Позже мы рассмотрим "очищенные" и увидим разницу.

# %% [markdown]
# ### Посчитаем статистическую значимость различий в конверсии между группами по «очищенным» данным

# %% [markdown]
# Примем за аномальных пользователей тех, кто совершил от `2` заказа или совершил заказ дороже `28 000 ед`. Так мы уберём `5%` пользователей с наибольшим числом заказов и от `1%` до `5%` пользователей с дорогими заказами.

# %%
print('Граница аномалий заказов:',np.percentile(ordersByUsers['orders'], (95)))
print('Граница аномалий выручки:',np.percentile(orders['revenue'], (95)).round())

usersWithManyOrders = pd.concat(
    [
        ordersByUsersA[ordersByUsersA['orders'] > np.percentile(ordersByUsers['orders'], (95))]['visitorId'],
        ordersByUsersB[ordersByUsersB['orders'] > np.percentile(ordersByUsers['orders'], (95))]['visitorId'],
    ],
    axis=0,
)
usersWithExpensiveOrders = orders[orders['revenue'] > np.percentile(orders['revenue'], (95))]['visitorId']
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)

# посмотрим первые 5 строк таблицы abnormalUsers
display(abnormalUsers.head(5))

# узнаем, сколько всего аномальных пользователей атрибутом shape
display(abnormalUsers.shape[0])
# Out:
# Граница аномалий заказов: 2.0
# Граница аномалий выручки: 28000.0
# 1099    148427295
# 18      199603092
# 928     204675465
# 23      237748145
# 37      249864742
# Name: visitorId, dtype: int64
# 74

# %% [markdown]
# Всего `74` аномальных пользователя

# %% [markdown]
# Сформулируем гипотезы:
#  * Нулевая: различия в конверсиях между группами нет
#  * Альтернативная: различия в конверсиях между группами есть

# %% [markdown]
# Узнаем, как их действия повлияли на результаты теста.

# %%
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[
            np.logical_not(ordersByUsersA['visitorId'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                visitors[visitors['group']=='A']['visitors'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleBFiltered = pd.concat(
    [
        ordersByUsersB[
            np.logical_not(ordersByUsersB['visitorId'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                visitors[visitors['group']=='B']['visitors'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %%
# применим статистический критерий Манна-Уитни к полученным выборкам:
print('p-value равен:', '{0:.3f}'.format(st.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1]))
print('Относительный прирост конверсии группы B равен:','{0:.3f}'.format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# p-value равен: 0.013
# Относительный прирост конверсии группы B равен: 0.173

# %% [markdown]
# ### Вывод по статистической значимость различий в конверсии между группами по «очищенным» данным
# Первое число — `p-value = 0.013` меньше `0.05`. Значит, нулевую гипотезу о том, что различия в конверсиях между группами нет, отвергаем. По сырым данным `p-value = 0.017` не большая разница. Относительный прирост конверсии группы `B` равен `17.3%`. По сырым данным относительный прирост конверсии группы `B` равен `13.8%`.

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным

# %%
print(
    'p-value равен:','{0:.3f}'.format(
        st.mannwhitneyu(
            orders[
                np.logical_and(
                    orders['group'] == 'A',
                    np.logical_not(orders['visitorId'].isin(abnormalUsers)),
                )
            ]['revenue'],
            orders[
                np.logical_and(
                    orders['group'] == 'B',
                    np.logical_not(orders['visitorId'].isin(abnormalUsers)),
                )
            ]['revenue'],
        )[1]
    )
)

print(
    'Средний чек группы B меньше на:','{0:.3f}'.format(
        orders[
            np.logical_and(
                orders['group'] == 'B',
                np.logical_not(orders['visitorId'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        / orders[
            np.logical_and(
                orders['group'] == 'A',
                np.logical_not(orders['visitorId'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# p-value равен: 0.738
# Средний чек группы B меньше на: -0.020

# %% [markdown]
# ### Вывод по статистической значимости различий в среднем чеке заказа между группами по «очищенным» данным
# Первое число — `p-value = 0.738` значительно больше `0.05`. Значит, нулевую гипотезу о том, что различия в в среднем чеке заказа между группами нет, не отвергаем. В сырых данных этот показатель был `0.729`. Средний чек группы `B` оказался меньше на `2%` — среднего чека группы `A`. По сырым данным средний чек группы `B` был больше на `25.9%` — среднего чека группы `A`. Если смотреть на очищенные данные, то разницы в среднем чеке между группами `A` и `B` почти нет.

# %% [markdown]
# ## Общий вывод
# Гипотезу о том, что различия в конверсиях между группами нет, отвергаем. Относительный прирост конверсии группы `B` равен `17.3%`. По сырым данным относительный прирост конверсии группы `B` равен `13.8%`.
#
# Средний чек группы `B` оказался меньше на `2%` — среднего чека группы `A`. По сырым данным средний чек группы `B` был больше на `25.9%` — среднего чека группы `A`. Если смотреть на очищенные данные, то разницы в среднем чеке между группами `A` и `B` почти нет.
#
# Решение следущее: остановить тест, зафиксировать победу группы `B`, т.к. разница между группами есть, её показатели конверсии выше группы `A`.
